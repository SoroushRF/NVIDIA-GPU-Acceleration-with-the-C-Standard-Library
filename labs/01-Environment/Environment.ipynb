# %% [markdown]
# ![DLI Header](../images/DLI_Header.png)

# %% [markdown]
# # Your Compute Environment

# %% [markdown]
# This [JupyterLab](https://catalog.ngc.nvidia.com/orgs/nvidia/containers/nvhpc) environment is running on a cloud VM backed by one or more NVIDIA GPUs using an [NVIDIA HPC SDK Docker container provided by NGC](https://catalog.ngc.nvidia.com/orgs/nvidia/containers/nvhpc).

# %% [markdown]
# ## JupyterLab

# %% [markdown]
# For anyone unfamiliar with JupyterLab, you can execute *code* cells (those with `[ ]` in front of them) after selecting them by clicking the ▶️ button above, or by using either `SHIFT+ENTER` or `CTRL+ENTER`. *Code* cells by default are Python, however, when prefixed with `!`, like those below, the cells will run shell commands instead. We will be using the `!` extensively in these materials to compile and run C++ programs.

# %% [markdown]
# ## Available GPU(s) and CPU

# %% [markdown]
#  Execute the two code cells immediately below to get information about the GPU(s) and CPU available to you.

# %%
# !nvidia-smi # Get information about the available GPU(s)

# %%
# !lscpu # Get information about this system's CPU

# %% [markdown]
# ## NVIDIA HPC SDK on NGC

# %% [markdown]
# The [NVIDIA HPC SDK](https://developer.nvidia.com/hpc-sdk) is a comprehensive suite of compilers, libraries and tools for HPC. In this interactive environment we are using it by way of a Docker container provided by by [NVIDIA NGC](https://www.nvidia.com/en-us/gpu-cloud/), which [you can download](https://catalog.ngc.nvidia.com/orgs/nvidia/containers/nvhpc) free of cost for use in your own projects.

# %% [markdown]
# ## Available Compilers

# %% [markdown]
# You will be working with several compilers provided in the HPC SDK, primarily for the sake of performance comparison as you learn to write applications that can benefit from the massive parallelism of GPUs. Execute the cell below to see the versions of the compilers we will use today.

# %%
# !g++ --version
# !clang++ --version
# !nvc++ --version

# %% [markdown]
# ## Next

# %% [markdown]
# Please proceed to [the next notebook](../02-DAXPY-Intro/Starting-Point-DAXPY.ipynb).
